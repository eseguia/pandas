# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('survey_stack_overflow.csv', index_col = 'ResponseId' )
#index_col to set index when loading, instead of doing it later with set_index

# %%
df.shape
# Out:
# (83439, 47)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
pd.set_option('display.max_columns',48)
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv')
schema_df
# Out:
#        qid          qname                                           question  \
# 0    QID16             S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12       MetaInfo                                  Browser Meta Info
# 2     QID1             S1  <span style="font-size:22px; font-family: aria...
# 3     QID2     MainBranch  Which of the following options best describes ...
# 4    QID24     Employment  Which of the following best describes your cur...
# ..     ...            ...                                                ...
# 43  QID124  Accessibility  Which of the following describe you, if any? P...
# 44  QID125   MentalHealth  Which of the following describe you, if any? P...
# 45  QID131             S6  <span style="font-size:22px;"><strong>Final Qu...
# 46  QID132   SurveyLength  How do you feel about the length of the survey...
# 47  QID133     SurveyEase  How easy or difficult was this survey to compl...
#
#     force_resp  type selector
# ...

# %%
df_arg = df.copy()[df['Country'] == 'Argentina']

df_arg
# Out:
#                                                    MainBranch  \
# ResponseId
# 290                            I am a developer by profession
# 484                            I am a developer by profession
# 1046                   I am a student who is learning to code
# 1202                           I am a developer by profession
# 1327        I am not primarily a developer, but I write co...
# ...                                                       ...
# 83021                          I am a developer by profession
# 83122                          I am a developer by profession
# 83196                          I am a developer by profession
# 83269                          I am a developer by profession
# 83380                          I am a developer by profession
#
#                                                    Employment    Country  \
# ResponseId
# 290                                        Employed full-time  Argentina
# ...

# %%
df_arg['EdLevel'].value_counts()
# Out:
# Some college/university study without earning a degree                                228
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          146
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     82
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        45
# Professional degree (JD, MD, etc.)                                                     30
# Associate degree (A.A., A.S., etc.)                                                    28
# Primary/elementary school                                                              11
# Other doctoral degree (Ph.D., Ed.D., etc.)                                              9
# Something else                                                                          8
# Name: EdLevel, dtype: int64

# %%
df_arg.loc[0:83379,'ConvertedCompYearly'].sum()/len(df_arg)
# not discarding the NaN values (so it's a higher value)
# Out:
# 32123.30834752981

# %%
df_arg.set_index('ConvertedCompYearly')
#change indexing
#inplace = True to save changes to df and not just display them once
# Out:
#                                                             MainBranch  \
# ConvertedCompYearly
# 75000.0                                 I am a developer by profession
# 279774.0                                I am a developer by profession
# NaN                             I am a student who is learning to code
# 100000.0                                I am a developer by profession
# 14016.0              I am not primarily a developer, but I write co...
# ...                                                                ...
# 56400.0                                 I am a developer by profession
# 48660.0                                 I am a developer by profession
# 21600.0                                 I am a developer by profession
# 48660.0                                 I am a developer by profession
# NaN                                     I am a developer by profession
#
#                                                             Employment  \
# ...

# %%
#df_arg.reset_index(inplace = True)

# %%
filt_py = (df['LanguageHaveWorkedWith'] == 'Python')
df_arg[filt_py]
# Out:
# <ipython-input-87-6607806d7333>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_arg[filt_py]
#                                                    MainBranch  \
# ResponseId
# 9255                   I am a student who is learning to code
# 10313                             I code primarily as a hobby
# 21299       I am not primarily a developer, but I write co...
# 27474                                           None of these
# 28067                          I am a developer by profession
# ...                                                       ...
# 50255                          I am a developer by profession
# 57004                          I am a developer by profession
# 66037       I am not primarily a developer, but I write co...
# 67015                          I am a developer by profession
# 71917       I am not primarily a developer, but I write co...
#
#                                                    Employment    Country  \
# ...

# %%
pd.set_option('display.max_rows',20)
df_ds_notnan = df[(df['DevType'] == 'Data scientist or machine learning specialist') & 
   (df['MainBranch'] == 'I am a developer by profession') &
   (df['ConvertedCompYearly'].notnull()) &
   (df['LanguageHaveWorkedWith'].str.contains('Python'))]
df_ds_notnan
# Out:
#                                 MainBranch          Employment  \
# ResponseId
# 10          I am a developer by profession  Employed full-time
# 78          I am a developer by profession  Employed full-time
# 225         I am a developer by profession  Employed full-time
# 379         I am a developer by profession  Employed full-time
# 587         I am a developer by profession  Employed full-time
# ...                                    ...                 ...
# 82274       I am a developer by profession  Employed full-time
# 82760       I am a developer by profession  Employed full-time
# 82907       I am a developer by profession  Employed full-time
# 82922       I am a developer by profession  Employed full-time
# 83113       I am a developer by profession  Employed full-time
#
#                              Country        US_State UK_Country  \
# ResponseId
# 10                            Sweden             NaN        NaN
# ...

# %%
df_ds_notnan['ConvertedCompYearly'].sum()/len(df_ds_notnan)
# Out:
# 121389.26702997275

# %%
df_ds_notnan.sort_values('ConvertedCompYearly')[120:135]
# Out:
#                                 MainBranch  \
# ResponseId
# 18347       I am a developer by profession
# 40784       I am a developer by profession
# 47977       I am a developer by profession
# 43677       I am a developer by profession
# 56233       I am a developer by profession
# 68304       I am a developer by profession
# 65711       I am a developer by profession
# 42216       I am a developer by profession
# 80890       I am a developer by profession
# 33253       I am a developer by profession
# 38693       I am a developer by profession
# 74856       I am a developer by profession
# 14550       I am a developer by profession
# 838         I am a developer by profession
# 45286       I am a developer by profession
#
#                                                    Employment      Country  \
# ResponseId
# 18347                                      Employed full-time        Italy
# 40784                                      Employed full-time        India
# ...

# %%
#df.columns = [x.lower() for x in df.columns]
#df.columns = df.columns.str.replace(' ', '_')

# %%
df.rename(columns = {'ResponseId':'Id'}, inplace = True)

# %%
df.loc[1,'Country'] = ['Russia']
#changing value of row

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
# 0                                                         NaN
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
filt = (df['Country'] == 'Tuvalu')
df[filt]
#filtering by country
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 61691       I am a student who is learning to code  Student, part-time
#
#            Country US_State UK_Country                             EdLevel  \
# ResponseId
# 61691       Tuvalu      NaN        NaN  Professional degree (JD, MD, etc.)
#
#               Age1stCode                                          LearnCode  \
# ResponseId
# 61691       5 - 10 years  Other online resources (ex: videos, blogs, etc...
#
#            YearsCode YearsCodePro DevType OrgSize Currency  CompTotal  \
# ResponseId
# 61691              9          NaN     NaN     NaN      NaN        NaN
#
#            CompFreq                             LanguageHaveWorkedWith  \
# ResponseId
# 61691           NaN  Assembly;Bash/Shell;C;C++;HTML/CSS;Java;JavaSc...
#
#            LanguageWantToWorkWith                    DatabaseHaveWorkedWith  \
# ResponseId
# ...

# %%
df.loc[filt, 'ConvertedCompYearly'] = 27000
df[filt]
#update row of filter on a specific column
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 61691       I am a student who is learning to code  Student, part-time
#
#            Country US_State UK_Country                             EdLevel  \
# ResponseId
# 61691       Tuvalu      NaN        NaN  Professional degree (JD, MD, etc.)
#
#               Age1stCode                                          LearnCode  \
# ResponseId
# 61691       5 - 10 years  Other online resources (ex: videos, blogs, etc...
#
#            YearsCode YearsCodePro DevType OrgSize Currency  CompTotal  \
# ResponseId
# 61691              9          NaN     NaN     NaN      NaN        NaN
#
#            CompFreq                             LanguageHaveWorkedWith  \
# ResponseId
# 61691           NaN  Assembly;Bash/Shell;C;C++;HTML/CSS;Java;JavaSc...
#
#            LanguageWantToWorkWith                    DatabaseHaveWorkedWith  \
# ResponseId
# ...

# %%
df['Country'].apply(len)
#applies a function to a column
# Out:
# ResponseId
# 1         6
# 2        11
# 3        18
# 4         7
# 5        52
#          ..
# 83436     5
# 83437    24
# 83438     6
# 83439     6
# 0         6
# Name: Country, Length: 83440, dtype: int64

# %%
df.apply(len)
#apply to all series   == len(df['something'])
# Out:
# MainBranch             83440
# Employment             83440
# Country                83440
# US_State               83440
# UK_Country             83440
#                        ...
# Accessibility          83440
# MentalHealth           83440
# SurveyLength           83440
# SurveyEase             83440
# ConvertedCompYearly    83440
# Length: 47, dtype: int64

# %%
# df.applymap(len) applies to all df

# %%
df.rename(columns={'ConvertedCompYearly':'YearlyUSDSalary'})
df.rename(columns={'YearlyUSDSalary':'ConvertedCompYearly'})
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
# 0                                                         NaN
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df['garbage_info'] = df['US_State'] + ' ' + df['UK_Country']
#combine columns

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
# 0                                                         NaN
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.drop(columns=['UK_Country','US_State','garbage_info'], inplace = True)
#delete columns, lacks inplace

# %%
df.append({'Country':'Pascua Island'}, ignore_index = True)
#append a row
# Out:
#                                               MainBranch  \
# 0                         I am a developer by profession
# 1                 I am a student who is learning to code
# 2      I am not primarily a developer, but I write co...
# 3                         I am a developer by profession
# 4                         I am a developer by profession
# ...                                                  ...
# 83436                     I am a developer by profession
# 83437                     I am a developer by profession
# 83438                     I am a developer by profession
# 83439                                                NaN
# 83440                                                NaN
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# ...

# %%
pd.set_option('display.max_rows',200)
df_arg[['ConvertedCompYearly','CompTotal','Currency','CompFreq','YearsCode','YearsCodePro']][0:200].sort_values(by='ConvertedCompYearly')
# Out:
#             ConvertedCompYearly   CompTotal                   Currency  \
# ResponseId
# 16403                      84.0       450.0        ARS\tArgentine peso
# 8520                      132.0       680.0        ARS\tArgentine peso
# 7518                     1944.0     10000.0        ARS\tArgentine peso
# 10540                    4860.0     25000.0        ARS\tArgentine peso
# 10713                    6228.0     32000.0        ARS\tArgentine peso
# 25763                    7392.0     38000.0        ARS\tArgentine peso
# 28104                    7788.0     40000.0        ARS\tArgentine peso
# 21600                    7788.0     40000.0        ARS\tArgentine peso
# 21413                    7788.0     40000.0        ARS\tArgentine peso
# 17095                    7788.0     40000.0        ARS\tArgentine peso
# 17927                    8172.0     42000.0        ARS\tArgentine peso
# 25776                   10116.0     52000.0        ARS\tArgentine peso
# ...

# %%
df_arg['ConvertedCompYearly'].median()
# Out:
# 35712.0

# %%
df['ConvertedCompYearly'].median()
# Out:
# 56211.0

# %%
df_ds_notnan['ConvertedCompYearly'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
df_arg.median()
# Out:
# C:\Users\Emilio\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1113: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# US_State                    NaN
# UK_Country                  NaN
# CompTotal              100000.0
# ConvertedCompYearly     35712.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedCompYearly
# count  4.718300e+04         4.684500e+04
# mean   2.119407e+69         1.184242e+05
# std    4.603702e+71         5.272889e+05
# min    0.000000e+00         1.000000e+00
# 25%    1.600000e+04         2.702500e+04
# 50%    6.700000e+04         5.621100e+04
# 75%    1.400000e+05         1.000000e+05
# max    1.000000e+74         4.524131e+07

# %%
df_arg.describe()
# Out:
#           CompTotal  ConvertedCompYearly
# count  4.120000e+02           410.000000
# mean   3.356080e+05         45991.175610
# std    1.255272e+06         43648.370727
# min    0.000000e+00            84.000000
# 25%    3.500000e+04         19464.000000
# 50%    1.000000e+05         35712.000000
# 75%    2.000000e+05         58392.000000
# max    1.725000e+07        480000.000000

# %%
df_ds_notnan.describe()
# Out:
#           CompTotal  ConvertedCompYearly
# count  3.670000e+02         3.670000e+02
# mean   2.094396e+06         1.213893e+05
# std    1.255327e+07         4.543321e+05
# min    1.800000e+01         4.800000e+01
# 25%    3.675000e+04         2.592700e+04
# 50%    8.000000e+04         5.404900e+04
# 75%    2.215000e+05         1.084070e+05
# max    1.700000e+08         8.078700e+06

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
# France                                                   2708
# Brazil                                                   2254
# Poland                                                   1805
# Netherlands                                              1772
# Italy                                                    1666
# Australia                                                1646
# Spain                                                    1485
# Russian Federation                                       1474
# Sweden                                                   1196
# China                                                    1055
# ...

# %%
df_country = df.groupby(['Country'])

# %%
df_ar = df_country.get_group('Argentina')

# %%
df_ar.loc[df['Country']=='Argentina']['YearsCodePro'].value_counts()
# Out:
# 2                   43
# 3                   37
# 4                   35
# 15                  33
# Less than 1 year    28
# 5                   26
# 10                  25
# 8                   24
# 6                   23
# 20                  23
# 7                   22
# 1                   22
# 25                  18
# 12                  15
# 11                  12
# 9                   10
# 14                  10
# 18                  10
# 23                   9
# 13                   9
# 17                   8
# 30                   6
# 16                   6
# 22                   5
# 21                   4
# 19                   3
# 28                   2
# 32                   2
# 26                   2
# 24                   2
# 31                   1
# 35                   1
# 34                   1
# Name: YearsCodePro, dtype: int64
